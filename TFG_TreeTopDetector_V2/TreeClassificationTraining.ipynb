# %%
# !nvidia-smi
# Out:
# Sat Jun 14 21:33:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.142                Driver Version: 550.142        CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080        Off |   00000000:01:00.0 Off |                  N/A |
# |  0%   45C    P8             18W /  260W |    2207MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting ultralytics (from -r requirements.txt (line 1))
#   Downloading ultralytics-8.3.155-py3-none-any.whl.metadata (37 kB)
# Collecting opencv-python (from -r requirements.txt (line 2))
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting tk (from -r requirements.txt (line 3))
#   Downloading tk-0.1.0-py3-none-any.whl.metadata (693 bytes)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (3.8.4)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (1.13.0)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (2.2.2+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (0.17.2+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (4.66.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.11/site-packages (from ultralytics->-r requirements.txt (line 1)) (2.2.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics->-r requirements.txt (line 1))
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 1)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 1)) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics->-r requirements.txt (line 1)) (1.3.0)
# Downloading ultralytics-8.3.155-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.4 MB/s eta 0:00:00a 0:00:01
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 80.5 MB/s eta 0:00:00a 0:00:01
# Downloading tk-0.1.0-py3-none-any.whl (3.9 kB)
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: tk, opencv-python, ultralytics-thop, ultralytics
# Successfully installed opencv-python-4.11.0.86 tk-0.1.0 ultralytics-8.3.155 ultralytics-thop-2.0.14
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install onnx onnxruntime-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting onnx
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.11/site-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=4.25.1 in /opt/conda/lib/python3.11/site-packages (from onnx) (4.25.3)
# Requirement already satisfied: typing_extensions>=4.7.1 in /opt/conda/lib/python3.11/site-packages (from onnx) (4.11.0)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.11/site-packages (from onnxruntime-gpu) (24.3.25)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from onnxruntime-gpu) (24.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from onnxruntime-gpu) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 47.8 MB/s eta 0:00:0000:0100:01
# Downloading onnxruntime_gpu-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (283.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.2/283.2 MB 41.7 MB/s eta 0:00:0000:0100:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 435.9 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 524.1 MB/s eta 0:00:00
# Installing collected packages: onnx, humanfriendly, coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.18.0 onnxruntime-gpu-1.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import os

# %%
# model = YOLO("yolov8m.yaml")
model = YOLO("yolo11n-cls.pt")

# %%
model.train(
    data = os.path.join(os.getcwd(), "TreeClassification"),
    epochs = 50,
    imgsz=640,
    batch = -1, 
    plots = True, 
    overlap_mask = False,
    workers=0,
    #augmentation parameters
    hsv_h = 0.015,
    hsv_s = 0.7,
    hsv_v = 0.4,
    degrees = 0,
    translate = 0.1,
    scale = 0.5,
    shear= 0,
    perspective =0,
    flipud = 0,
    fliplr = 0.5,
    bgr = 0,
    mosaic = 0,
    mixup = 0.1,
    copy_paste = 0,
    erasing = 0.4,
    crop_fraction = 1
    )

metrics = model.val()  # evaluate model performance on the validation set
path = model.export(format="onnx")  # export the model to ONNX format
# Out:
# WARNING ⚠️ 'crop_fraction' is deprecated and will be removed in in the future.
# Ultralytics 8.3.155 🚀 Python-3.11.8 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 7967MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=-1, bgr=0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification, degrees=0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=0, multi_scale=False, name=train7, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=False, patience=100, perspective=0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/classify/train7, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# train: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/train... found 681 images in 3 classes ✅
# val: None...
# test: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/test... found 97 images in 3 classes ✅
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLO11n-cls summary: 86 layers, 1,534,947 parameters, 1,534,947 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# AutoBatch: Computing optimal batch size for imgsz=640 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA GeForce RTX 2080) 7.78G total, 0.32G reserved, 0.05G allocated, 7.41G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      1534947       3.251         0.312         26.97         304.4        (1, 3, 640, 640)                  (1, 3)
#      1534947       6.503         0.409         10.43         167.5        (2, 3, 640, 640)                  (2, 3)
#      1534947       13.01         0.583         14.18         117.1        (4, 3, 640, 640)                  (4, 3)
#      1534947       26.01         0.910         14.59           142        (8, 3, 640, 640)                  (8, 3)
#      1534947       52.02         1.544         14.59         110.3       (16, 3, 640, 640)                 (16, 3)
# AutoBatch: Using batch-size 46 for CUDA:0 4.37G/7.78G (56%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 509.5±139.3 MB/s, size: 22.6 KB)
# train: Scanning /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/train... 681 images, 0 corrupt: 100%|██████████| 681/681 [00:00<00:00, 2751.76it/s]
# train: New cache created: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 472.2±266.1 MB/s, size: 23.0 KB)
# val: Scanning /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/test... 97 images, 0 corrupt: 100%|██████████| 97/97 [00:00<00:00, 3024.08it/s]
# val: New cache created: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.000359375), 40 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/classify/train7
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50      4.48G     0.9846         46        640:   0%|          | 0/15 [00:01<?, ?it/s]Exception in thread Thread-27 (plot_images):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#        1/50      4.48G     0.9846         46        640:   7%|▋         | 1/15 [00:01<00:24,  1.76s/it]    self.run()
#   File "/opt/conda/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/conda/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: plot_images() got an unexpected keyword argument 'batch_idx'
#        1/50      4.48G      0.994         46        640:  13%|█▎        | 2/15 [00:03<00:20,  1.55s/it]Exception in thread Thread-28 (plot_images):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/conda/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: plot_images() got an unexpected keyword argument 'batch_idx'
#        1/50      4.48G     0.9801         46        640:  20%|██        | 3/15 [00:04<00:17,  1.49s/it]Exception in thread Thread-29 (plot_images):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/conda/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: plot_images() got an unexpected keyword argument 'batch_idx'
#        1/50      4.48G     0.6035         37        640: 100%|██████████| 15/15 [00:20<00:00,  1.37s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.37it/s]
#                    all      0.969          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50      3.97G    0.08498         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.22s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.82it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50      3.97G    0.07056         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.72it/s]
#                    all      0.959          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50      3.97G    0.07342         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.23s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.87it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50      3.97G    0.05987         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.91it/s]
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50      3.97G    0.07569         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.20s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.87it/s]
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50      3.97G    0.09544         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.96it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50      3.97G    0.09577         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.24s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.85it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50      3.97G    0.06154         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:00<00:00,  2.00it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50      3.97G    0.06005         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.24s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.89it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50      3.97G    0.06059         37        640: 100%|██████████| 15/15 [00:16<00:00,  1.13s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.80it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50      3.97G    0.07815         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.14s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]
#                    all      0.918          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50      3.97G    0.09829         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]
#                    all      0.959          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50      3.97G    0.06742         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.21s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
#                    all      0.938          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50      3.97G    0.06767         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.81it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50      3.97G     0.0545         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.22s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.94it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/50      3.97G    0.06534         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.85it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/50      3.97G    0.04962         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.24s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.88it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/50      3.97G    0.05718         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.14s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.89it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/50      3.97G    0.08186         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.24s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]
#                    all      0.959          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/50      3.97G    0.06352         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.21s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50      3.97G     0.0552         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.86it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50      3.97G    0.06271         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.83it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50      3.97G    0.05485         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.21s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.83it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50      3.97G    0.05122         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.26s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.85it/s]
#                    all      0.959          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50      3.97G    0.05501         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.74it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50      3.97G     0.0624         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.22s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.83it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50      3.97G    0.06364         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50      3.97G    0.05049         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.94it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50      3.97G    0.05239         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.97it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50      3.97G    0.04649         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50      3.97G    0.04669         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50      3.97G    0.05821         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.20s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.91it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50      3.97G     0.0529         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.24s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
#                    all      0.959          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50      3.97G    0.05573         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.95it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50      3.97G    0.04215         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.26s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.89it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50      3.97G    0.04544         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.22s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.84it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50      3.97G    0.04562         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.85it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50      3.97G    0.04652         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.93it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50      3.97G    0.04527         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.20s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50      3.97G    0.07284         46        640:   0%|          | 0/15 [00:01<?, ?it/s]Exception in thread Thread-30 (plot_images):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#       41/50      3.97G    0.07284         46        640:   7%|▋         | 1/15 [00:01<00:19,  1.39s/it]    self.run()
#   File "/opt/conda/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/conda/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: plot_images() got an unexpected keyword argument 'batch_idx'
#       41/50      3.97G    0.04151         46        640:   7%|▋         | 1/15 [00:02<00:19,  1.39s/it]Exception in thread Thread-31 (plot_images):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#       41/50      3.97G    0.04151         46        640:  13%|█▎        | 2/15 [00:02<00:17,  1.32s/it]    self.run()
#   File "/opt/conda/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/conda/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: plot_images() got an unexpected keyword argument 'batch_idx'
#       41/50      3.97G    0.07967         46        640:  13%|█▎        | 2/15 [00:03<00:17,  1.32s/it]Exception in thread Thread-32 (plot_images):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#       41/50      3.97G    0.07967         46        640:  20%|██        | 3/15 [00:03<00:15,  1.29s/it]    self.run()
#   File "/opt/conda/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/conda/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: plot_images() got an unexpected keyword argument 'batch_idx'
#       41/50      3.97G    0.04552         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.23s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.95it/s]
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50      3.97G    0.04557         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50      3.97G    0.04346         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.93it/s]
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50      3.97G     0.0456         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.25s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.96it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50      3.97G     0.0388         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.22s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.94it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50      3.97G    0.04015         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.24s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.86it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50      3.97G    0.04259         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.23s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.89it/s]
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50      3.97G    0.04369         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.88it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50      3.97G    0.03447         37        640: 100%|██████████| 15/15 [00:18<00:00,  1.24s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.87it/s]
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50      3.97G    0.04041         37        640: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.85it/s]
#                    all      0.979          1
#
# 50 epochs completed in 0.272 hours.
# Optimizer stripped from runs/classify/train7/weights/last.pt, 3.2MB
# Optimizer stripped from runs/classify/train7/weights/best.pt, 3.2MB
#
# Validating runs/classify/train7/weights/best.pt...
# Ultralytics 8.3.155 🚀 Python-3.11.8 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 7967MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,529,867 parameters, 0 gradients, 3.2 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/train... found 681 images in 3 classes ✅
# val: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/test... found 97 images in 3 classes ✅
# test: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/test... found 97 images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100%|██████████| 2/2 [00:01<00:00,  1.72it/s]
#                    all       0.99          1
# Speed: 0.4ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train7
# Ultralytics 8.3.155 🚀 Python-3.11.8 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 7967MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,529,867 parameters, 0 gradients, 3.2 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/train... found 681 images in 3 classes ✅
# val: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/test... found 97 images in 3 classes ✅
# test: /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/test... found 97 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 636.1±249.1 MB/s, size: 23.0 KB)
# val: Scanning /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification/test... 97 images, 0 corrupt: 100%|██████████| 97/97 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:01<00:00,  2.63it/s]
#                    all       0.99          1
# Speed: 2.8ms preprocess, 1.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train72
# Ultralytics 8.3.155 🚀 Python-3.11.8 torch-2.2.2+cu121 CPU (Intel Core(TM) i7-6700K 4.00GHz)
#
# PyTorch: starting from 'runs/classify/train7/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 3) (3.0 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 17...
# ONNX: slimming with onnxslim 0.1.57...
# ONNX: export success ✅ 2.1s, saved as 'runs/classify/train7/weights/best.onnx' (5.9 MB)
#
# Export complete (2.9s)
# Results saved to /home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/runs/classify/train7/weights
# Predict:         yolo predict task=classify model=runs/classify/train7/weights/best.onnx imgsz=640
# Validate:        yolo val task=classify model=runs/classify/train7/weights/best.onnx imgsz=640 data=/home/jovyan/work/PDD-JonathanGonzalez/TFG_TreeTopDetector_V2/TreeClassification
# Visualize:       https://netron.app
